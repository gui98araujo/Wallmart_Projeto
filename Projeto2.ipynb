# %% [markdown]
# <a href="https://colab.research.google.com/github/gui98araujo/Wallmart_Projeto/blob/main/Projeto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('/content/Walmart.csv')

# %%
import seaborn as sns

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df2=df.drop(['Date'],axis=1)
for column in df2:
    df2[column].plot(kind='box', showmeans=True)
    plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
repeticoes_data = df['Date'].value_counts()

# %%
repeticoes_data
# Out:
# 2010-05-02    45
# 2011-12-23    45
# 2011-11-11    45
# 2011-11-18    45
# 2011-11-25    45
#               ..
# 2011-07-01    45
# 2011-01-14    45
# 2011-01-21    45
# 2011-01-28    45
# 2012-10-26    45
# Name: Date, Length: 143, dtype: int64

# %%
correlacao = df.corr()

# %%
correlacao.drop(correlacao.columns.difference(['Weekly_Sales']), 1, inplace=True)
correlacao
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#               Weekly_Sales
# Store            -0.335332
# Weekly_Sales      1.000000
# Holiday_Flag      0.036891
# Temperature      -0.063810
# Fuel_Price        0.009464
# CPI              -0.072634
# Unemployment     -0.106176

# %%
vendasFeriado=df[df['Holiday_Flag']==1]

# %%
vendasFeriado
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 31        1 2010-10-09    1507460.69             1        78.69       2.565
# 42        1 2010-11-26    1955624.11             1        64.52       2.735
# 47        1 2010-12-31    1367320.01             1        48.43       2.943
# 53        1 2011-11-02    1649614.93             1        36.39       3.022
# ...     ...        ...           ...           ...          ...         ...
# 6375     45 2011-09-09     746129.56             1        71.48       3.738
# 6386     45 2011-11-25    1170672.94             1        48.71       3.492
# 6391     45 2011-12-30     869403.63             1        37.79       3.389
# 6397     45 2012-10-02     803657.12             1        37.00       3.640
# 6427     45 2012-07-09     766512.66             1        75.70       3.911
#
#              CPI  Unemployment
# ...

# %%
mediaFeriado=vendasFeriado["Weekly_Sales"].mean()

# %%
repeticoes_store = df['Store'].value_counts()
repeticoes_store
# Out:
# 1     143
# 24    143
# 26    143
# 27    143
# 28    143
# 29    143
# 30    143
# 31    143
# 32    143
# 33    143
# 34    143
# 35    143
# 36    143
# 37    143
# 38    143
# 39    143
# 40    143
# 41    143
# 42    143
# 43    143
# 44    143
# 25    143
# 23    143
# 2     143
# 22    143
# 3     143
# 4     143
# 5     143
# 6     143
# 7     143
# 8     143
# 9     143
# 10    143
# 11    143
# 12    143
# 13    143
# 14    143
# 15    143
# 16    143
# 17    143
# 18    143
# 19    143
# 20    143
# 21    143
# 45    143
# Name: Store, dtype: int64

# %%
vendasFeriado['Store'].value_counts()
# Out:
# 1     10
# 24    10
# 26    10
# 27    10
# 28    10
# 29    10
# 30    10
# 31    10
# 32    10
# 33    10
# 34    10
# 35    10
# 36    10
# 37    10
# 38    10
# 39    10
# 40    10
# 41    10
# 42    10
# 43    10
# 44    10
# 25    10
# 23    10
# 2     10
# 22    10
# 3     10
# 4     10
# 5     10
# 6     10
# 7     10
# 8     10
# 9     10
# 10    10
# 11    10
# 12    10
# 13    10
# 14    10
# 15    10
# 16    10
# 17    10
# 18    10
# 19    10
# 20    10
# 21    10
# 45    10
# Name: Store, dtype: int64

# %%
vendasNaoFeriado=df[df['Holiday_Flag']==0]
mediaNaoFeriado=vendasNaoFeriado['Weekly_Sales'].mean()

# %%
mediaNaoFeriado
# Out:
# 1041256.3802088555

# %%
mediaFeriado
# Out:
# 1122887.8923555557

# %%
vendasTotal=df.groupby('Store').agg({ 'Weekly_Sales': 'sum'}).sort_values(by=['Weekly_Sales'], ascending=False)
vendasTotal.head()
# Out:
#        Weekly_Sales
# Store
# 20     3.013978e+08
# 4      2.995440e+08
# 14     2.889999e+08
# 13     2.865177e+08
# 2      2.753824e+08

# %%
vendasTotal=df.groupby('Store').agg({ 'Weekly_Sales': 'sum', 'Unemployment':'mean','Fuel_Price' : 'mean', 'Temperature' : 'mean'}).sort_values(by=['Store'], ascending=False)

# %%
vendasTotal
# Out:
#        Weekly_Sales  Unemployment  Fuel_Price  Temperature
# Store
# 45     1.123953e+08      8.648748    3.417608    57.790979
# 44     4.329309e+07      6.735622    3.286147    53.697133
# 43     9.056544e+07      9.934804    3.219699    68.877692
# 42     7.956575e+07      8.362965    3.575923    72.241189
# 41     1.813419e+08      6.973378    3.241559    48.410350
# 40     1.378703e+08      4.796014    3.441741    47.674545
# 39     2.074455e+08      7.869049    3.219699    70.597343
# 38     5.515963e+07     13.116483    3.606420    70.262797
# 37     7.420274e+07      7.869049    3.219699    71.160350
# 36     5.341221e+07      7.869049    3.204203    71.160350
# 35     1.315207e+08      8.788573    3.417608    57.311119
# 34     1.382498e+08      9.934804    3.216972    58.495874
# 33     3.716022e+07      8.533154    3.575923    76.728182
# 32     1.668192e+08      8.585734    3.241559    52.747552
# 31     1.996139e+08      7.623846    3.219699    68.847622
# ...

# %%
vendasTotal.rename(columns={"Weekly_Sales":"Sales"}, inplace=True)

# %%
correlacao = vendasTotal.corr()

# %%
correlacao.drop(correlacao.columns.difference(['Sales']), 1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
correlacao
# Out:
#                  Sales
# Sales         1.000000
# Unemployment -0.112281
# Fuel_Price    0.067734
# Temperature  -0.076388

# %%
mediaTotal=vendasTotal.Sales.mean()

# %%
mediaTotal
# Out:
# 149715977.49133334

# %%
vendasTotal=vendasTotal[vendasTotal['Sales']>=mediaTotal]

# %%
lista=vendasTotal.query('Sales >= 149715977.49133334').index.tolist()

# %%
df = df[df['Store'].isin(lista)]

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 5858     41 2012-09-28    1307928.01             0        56.08       3.789
# 5859     41 2012-05-10    1400160.95             0        50.14       3.779
# 5860     41 2012-12-10    1409544.97             0        39.38       3.760
# 5861     41 2012-10-19    1326197.24             0        49.56       3.750
# 5862     41 2012-10-26    1316542.59             0        41.80       3.686
#
#              CPI  Unemployment
# ...

# %%
vendasNaoFeriado=df[df['Holiday_Flag']==0]
mediaNaoFeriado=vendasNaoFeriado['Weekly_Sales'].mean()

# %%
mediaFeriado=vendasFeriado["Weekly_Sales"].mean()

# %%
vendasFeriado=df[df['Holiday_Flag']==1]

# %%
mediaFeriado
# Out:
# 1703072.4314736843

# %%
mediaNaoFeriado
# Out:
# 1580076.7479540957

# %%
correlacao = df.corr()

# %%
correlacao.drop(correlacao.columns.difference(['Weekly_Sales']), 1, inplace=True)
correlacao
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#               Weekly_Sales
# Store            -0.432528
# Weekly_Sales      1.000000
# Holiday_Flag      0.080515
# Temperature      -0.017533
# Fuel_Price       -0.030458
# CPI              -0.040522
# Unemployment     -0.200171

# %%
vendasTotal.describe()
# Out:
#               Sales  Unemployment  Fuel_Price  Temperature
# count  1.900000e+01     19.000000   19.000000    19.000000
# mean   2.271809e+08      7.821874    3.365282    60.885061
# std    4.719365e+07      1.620995    0.156675     8.647537
# min    1.551147e+08      4.796014    3.216972    48.410350
# 25%    1.939894e+08      7.089406    3.219699    53.534196
# 50%    2.074455e+08      7.623846    3.286147    57.790979
# 75%    2.735001e+08      8.404990    3.508832    69.273811
# max    3.013978e+08     13.116483    3.606420    72.480769

# %%
vendasTotal[vendasTotal['Unemployment']<7.623846]
# Out:
#               Sales  Unemployment  Fuel_Price  Temperature
# Store
# 41     1.813419e+08      6.973378    3.241559    48.410350
# 23     1.987506e+08      4.796014    3.441741    48.805105
# 20     3.013978e+08      7.371413    3.417608    55.451399
# 13     2.865177e+08      7.001825    3.286147    53.697133
# 11     1.939628e+08      7.176986    3.219699    72.480769
# 6      2.237561e+08      6.606902    3.219699    69.700000
# 4      2.995440e+08      5.964692    3.216972    62.253357
# 1      2.224028e+08      7.610420    3.219699    68.306783

# %%
ano1=df[df['Date'] < '01-01-2011']

# %%
ano1
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6335     45 2010-03-12     879244.90             0        40.93       3.046
# 6336     45 2010-10-12    1002364.34             0        30.54       3.109
# 6337     45 2010-12-17    1123282.85             0        30.51       3.140
# 6338     45 2010-12-24    1682862.03             0        30.59       3.141
# 6339     45 2010-12-31     679156.20             1        29.67       3.179
#
#              CPI  Unemployment
# ...

# %%
ano3=df[df['Date'] >= '01-01-2012']

# %%
ano3
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 100       1 2012-06-01    1550369.92             0        49.01       3.157
# 101       1 2012-01-13    1459601.17             0        48.53       3.261
# 102       1 2012-01-20    1394393.84             0        54.11       3.268
# 103       1 2012-01-27    1319325.59             0        54.26       3.290
# 104       1 2012-03-02    1636339.65             0        56.55       3.360
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
vendasAno1=ano1.groupby('Store').agg({ 'Weekly_Sales': 'sum', 'Unemployment':'mean','Fuel_Price' : 'mean', 'Temperature' : 'mean', 'CPI': 'mean'}).sort_values(by=['Store'], ascending=False)

# %%
vendasAno1=ano1.groupby('Store').agg(Sales=('Weekly_Sales', 'sum'),'Fuel_Price' : 'mean', 'Temperature' : 'mean', 'CPI': 'mean').sort_values(by=['Store'], ascending=False).reset_index()
# Out:
#   File "<ipython-input-20-2f328a1e6c10>", line 1
#     vendasAno1=ano1.groupby('Store').agg(Sales=('Weekly_Sales', 'sum'),'Fuel_Price' : 'mean', 'Temperature' : 'mean', 'CPI': 'mean').sort_values(by=['Store'], ascending=False).reset_index()
#                                                                                     ^
# SyntaxError: invalid syntax

# %%
vendasAno1
# Out:
#     Store         Sales
# 0      45  3.853634e+07
# 1      44  1.360752e+07
# 2      43  3.153701e+07
# 3      42  2.549809e+07
# 4      41  5.773822e+07
# 5      40  4.635736e+07
# 6      39  6.578228e+07
# 7      38  1.658779e+07
# 8      37  2.450847e+07
# 9      36  2.115313e+07
# 10     35  5.219597e+07
# 11     34  4.615042e+07
# 12     33  1.276683e+07
# 13     32  5.519094e+07
# 14     31  6.556027e+07
# 15     30  2.173909e+07
# 16     29  2.694683e+07
# 17     28  6.477876e+07
# 18     27  9.001318e+07
# 19     26  4.839070e+07
# 20     25  3.513627e+07
# 21     24  6.689065e+07
# 22     23  6.770911e+07
# 23     22  5.086528e+07
# 24     21  3.763111e+07
# 25     20  1.017331e+08
# 26     19  7.258053e+07
# 27     18  5.597842e+07
# 28     17  4.110492e+07
# 29     16  2.472863e+07
# 30     15  3.202353e+07
# 31     14  1.054622e+08
# 32     13  9.527274e+07
# 33     12  4.837038e+07
# 34     11  6.525514e+07
# 35     10  9.447220e+07
# 36      9  2.512922e+07
# ...

# %%
vendasAno3=ano3.groupby('Store').agg({ 'Weekly_Sales': 'sum', 'Unemployment':'mean','Fuel_Price' : 'mean', 'Temperature' : 'mean'}).sort_values(by=['Store'], ascending=False)

# %%
comparacao=vendasAno3-vendasAno1

# %%
df[(df['Store']==1) & (df['Date']>'01-01-2012')]
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 100      1 2012-06-01    1550369.92             0        49.01       3.157
# 101      1 2012-01-13    1459601.17             0        48.53       3.261
# 102      1 2012-01-20    1394393.84             0        54.11       3.268
# 103      1 2012-01-27    1319325.59             0        54.26       3.290
# 104      1 2012-03-02    1636339.65             0        56.55       3.360
# 105      1 2012-10-02    1802477.43             1        48.02       3.409
# 106      1 2012-02-17    1819870.00             0        45.32       3.510
# 107      1 2012-02-24    1539387.83             0        57.25       3.555
# 108      1 2012-02-03    1688420.76             0        60.96       3.630
# 109      1 2012-09-03    1675431.16             0        58.76       3.669
# 110      1 2012-03-16    1677472.78             0        64.74       3.734
# ...

# %%
correlacao = comparacao.corr()
correlacao
# Out:
#               Weekly_Sales  Unemployment  Fuel_Price  Temperature
# Weekly_Sales      1.000000     -0.351974   -0.361511     0.422782
# Unemployment     -0.351974      1.000000    0.078484    -0.330259
# Fuel_Price       -0.361511      0.078484    1.000000    -0.665293
# Temperature       0.422782     -0.330259   -0.665293     1.000000

# %%
comparacao
# Out:
#        Weekly_Sales  Unemployment  Fuel_Price  Temperature
# Store
# 45      -5812713.20     -0.252766    0.918750     2.437597
# 44        579854.27     -2.280440    0.747585     4.722529
# 43      -4561772.02     -0.378912    0.853076     2.440988
# 42       -547730.06     -1.997839    0.947371     2.122631
# 41       -850380.72     -0.935189    0.848364     4.250950
# 40      -5184952.18     -1.261130    0.939383     0.673110
# 39        103386.53     -1.569682    0.853076     3.197185
# 38       2043278.93     -2.711153    0.959244     3.299084
# 37      -1895695.17     -1.569682    0.853076     3.621226
# 36      -7866655.16     -1.569682    0.904948     3.621226
# 35     -16958248.41     -0.145429    0.918750     2.039753
# 34      -4411252.64     -0.378912    0.830034     3.007689
# 33      -1331283.23     -2.290427    0.947371     2.606565
# 32      -4909820.68     -1.012177    0.848364     3.436860
# 31      -5675865.54     -1.406963    0.853076     2.977597
# ...

# %% [markdown]
# ## Filtro

# %%
df[(df['CPI']<145) & (df['Fuel_Price']<3.75) & (df['Temperature']<=60) & (df['Temperature']>=20) & (df['Unemployment']<10)]
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 429       4  05-02-2010    2135143.87             0        43.76       2.598
# 430       4  12-02-2010    2188307.39             1        28.84       2.573
# 431       4  19-02-2010    2049860.26             0        36.45       2.540
# 432       4  26-02-2010    1925728.84             0        41.36       2.590
# 433       4  05-03-2010    1971057.44             0        43.49       2.654
# ...     ...         ...           ...           ...          ...         ...
# 6257     44  02-03-2012     316687.22             0        32.36       3.242
# 6258     44  09-03-2012     303438.24             0        38.24       3.380
# 6259     44  16-03-2012     331965.95             0        52.50       3.529
# 6260     44  23-03-2012     296947.06             0        47.83       3.671
# 6261     44  30-03-2012     310027.29             0        53.20       3.734
#
#              CPI  Unemployment
# ...

# %%
lista=df_filtro['Store'].value_counts().index.tolist()

# %%
df.plot(kind="scatter",x="CPI",y="Weekly_Sales",alpha=0.4) #é possível segmentar CPi < 150

# %%
df.plot(kind="scatter",x="Temperature",y="Weekly_Sales",alpha=0.4)

# %%
df.plot(kind="scatter",x="Fuel_Price",y="Weekly_Sales",alpha=0.4)

# %%
df.plot(kind="scatter",x="Unemployment",y="Weekly_Sales",alpha=0.4)

# %%
df_final=df[df['Store'].isin(lista)]

# %%
df_final
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 429       4  05-02-2010    2135143.87             0        43.76       2.598
# 430       4  12-02-2010    2188307.39             1        28.84       2.573
# 431       4  19-02-2010    2049860.26             0        36.45       2.540
# 432       4  26-02-2010    1925728.84             0        41.36       2.590
# 433       4  05-03-2010    1971057.44             0        43.49       2.654
# ...     ...         ...           ...           ...          ...         ...
# 6287     44  28-09-2012     355307.94             0        64.80       3.821
# 6288     44  05-10-2012     337390.44             0        61.79       3.815
# 6289     44  12-10-2012     337796.13             0        55.10       3.797
# 6290     44  19-10-2012     323766.77             0        52.06       3.781
# 6291     44  26-10-2012     361067.07             0        46.97       3.755
#
#              CPI  Unemployment
# ...

# %%
df_final.groupby('Store').agg(Mean_Weekly_Sales=('Weekly_Sales','mean'),Median_Weekly_Sales=('Weekly_Sales','median'), Std_Weekly_Sales=('Weekly_Sales', 'std')).reset_index().sort_values(by=['Median_Weekly_Sales'], ascending=False)
# Out:
#     Store  Mean_Weekly_Sales  Median_Weekly_Sales  Std_Weekly_Sales
# 0       4       2.094713e+06           2073951.38     266201.442297
# 2      13       2.003620e+06           1958823.56     265506.995776
# 1      10       1.899425e+06           1827521.71     302262.062504
# 11     27       1.775216e+06           1731935.43     239930.135688
# 6      19       1.444999e+06           1408968.55     191722.638730
# 8      23       1.389864e+06           1358444.07     249788.038068
# 9      24       1.356755e+06           1339630.35     167745.677567
# 5      18       1.084718e+06           1060433.10     176641.510839
# 10     26       1.002912e+06            996723.58     110431.288141
# 7      22       1.028501e+06            996628.80     161251.350631
# 16     40       9.641280e+05            954233.87     119002.112858
# 14     34       9.667816e+05            950154.24     104630.164676
# 4      17       8.935814e+05            872817.62     112162.936087
# ...

# %%
# Cores dos boxplot
colors =  sns.set_style("whitegrid")

ax = sns.boxplot( x = "Store", y ="Weekly_Sales",data = df_final, linewidth=1, palette=colors)

# Adicionar label
ax.set_xlabel("Grade", fontsize = 15)
ax.set_ylabel("price", fontsize = 15)


# Aumentar tamanho da figura
ax.figure.set_dpi(100);

# %%
df[(df['Store']==4) & (df['Date']<'01-01-2011')]
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 429      4 2010-05-02    2135143.87             0        43.76       2.598
# 430      4 2010-12-02    2188307.39             1        28.84       2.573
# 431      4 2010-02-19    2049860.26             0        36.45       2.540
# 432      4 2010-02-26    1925728.84             0        41.36       2.590
# 433      4 2010-05-03    1971057.44             0        43.49       2.654
# 434      4 2010-12-03    1894324.09             0        49.63       2.704
# 435      4 2010-03-19    1897429.36             0        55.19       2.743
# 436      4 2010-03-26    1762539.30             0        39.91       2.752
# 437      4 2010-02-04    1979247.12             0        48.77       2.740
# 438      4 2010-09-04    1818452.72             0        54.16       2.773
# 439      4 2010-04-16    1851519.69             0        56.23       2.810
# ...

# %%
df.plot(kind='line', x='Date', y='Weekly_Sales')

# %%
df['month']=df['Date'].dt.to_period('M')

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment    month
# ...

# %%
x=df.groupby(['Store', 'month']).agg(vendas=('Weekly_Sales', 'sum')).reset_index()

# %%
y=x[x['Store']==38]

# %%
y.plot(kind='line', x='month', y='vendas')

# %%
x['month']
# Out:
# 0       2010-01
# 1       2010-02
# 2       2010-03
# 3       2010-04
# 4       2010-05
#          ...
# 1615    2012-08
# 1616    2012-09
# 1617    2012-10
# 1618    2012-11
# 1619    2012-12
# Name: month, Length: 1620, dtype: period[M]

# %%
x['vendas']
# Out:
# 0       1453329.50
# 1       6109082.18
# 2       5965143.02
# 3       5897939.82
# 4       9076140.38
#            ...
# 1615    2970160.06
# 1616    2915467.29
# 1617    3015101.40
# 1618     770487.37
# 1619     734464.36
# Name: vendas, Length: 1620, dtype: float64

# %%
pandas_df = x.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-380bc9ed0b10> in <module>
# ----> 1 pandas_df = x.to_pandas()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_pandas'
